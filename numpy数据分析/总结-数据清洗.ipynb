# %% [markdown]
# #### 处理缺失数据

# %% [markdown]
# ##### 填充或删除
# 检测isnull(),
# 删除 dropna,
# 填充 fillna,

# %% [markdown]
# #### 处理重复的数据

# %% [markdown]
# ##### 删除
# 检测重复数据 duplicated
# 删除重复数据 drop.duplicates

# %% [markdown]
# #### 数据类型不统一

# %% [markdown]
# ##### 数据类型转换

# %% [markdown]
# #### 部分数据包含数值和字符串

# %% [markdown]
# ##### 字符串处理

# %% [markdown]
# #### 部分数据存在异常值

# %% [markdown]
# ##### 删除

# %% [markdown]
# drop()

# %% [markdown]
# #### 少数数据不利于分析

# %% [markdown]
# ##### 替换

# %% [markdown]
# replace
