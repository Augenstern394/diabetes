# %%
import pandas as pd

# %%
f1 = open('./运动员信息表.csv')
df = pd.read_csv(f1)
df
# Out:
#        姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)      项目     省份
# 0     陈楠   女   1983年     35     197      90      篮球    山东省
# 1    白发全   男   1986年     32     175      64    铁人三项    云南省
# 2    陈晓佳   女   1988年     30     180      70      篮球    江苏省
# 3     陈倩   女   1987年     31     163      54  女子现代五项  江苏省
# 4    曹忠荣   男   1981年     37     180      73  男子现代五项    上海市
# ..    ... ..     ...    ...     ...     ...     ...    ...
# 174  赵芸蕾   女   1986年     32     173      62     羽毛球    湖北省
# 175   周琦   男   1996年     22     217      95      篮球   河南省
# 176  翟晓川   男   1993年     25     204     100      篮球   河北省
# 177  赵继伟   男   1995年     23     185      77      篮球    辽宁省
# 178  邹雨宸   男   1996年     22     208     108      篮球    辽宁省
#
# [179 rows x 8 columns]

# %%
def outer(df_basketball):
    '''
    计算bmi
    '''
    weight = df_basketball['体重(kg)']
    height = df_basketball['身高(cm)']
    sum_bmi = weight / (height/100)**2
    return sum_bmi

# %%
def range_data_group(arr):
    '''
    计算极差
    '''
    return arr.max()-arr.min()

# %%
data_groupby_project = df.groupby('项目')
for data in data_groupby_project:
    print(data)
# Out:
# ('举重',       姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目     省份
# 18   邓薇   女   1993年     25     158      60  举重    福建省
# 57  龙清泉   男   1990年     28     156      56  举重  湖南省
# 77  吕小军   男   1984年     34     172      77  举重    湖北省)
# ('乒乓球',        姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)   项目      省份
# 17    丁宁   女   1990年     28     170      63  乒乓球  黑龙江省
# 53   李晓霞   女   1988年     30     174      64  乒乓球     辽宁省
# 76    马龙   男   1988年     30     175      72  乒乓球     辽宁省
# 105   王宇   男   1991年     27     188      75  乒乓球   山东省
# 131   许昕   男   1990年     28     180      67  乒乓球     上海市
# 145   杨洋   男   1991年     27     183      75  乒乓球   山东省
# 156  张继科   男   1988年     30     181      70  乒乓球   山东省  )
# ('体操',        姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目   省份
# 158  张成龙   男   1989年     29     173      65  体操  山东省)
# ('击剑',        姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目     省份
# 92    沈晨   女   1990年     28     171      60  击剑  江苏省
# 104  孙玉洁   女   1992年     26     185      72  击剑    辽宁省
# ...

# %%
# 统计篮球运动员的平均年龄、身高、体重
df_basketball = dict([x for x in data_group])['篮球']
print(df_basketball)
avg_data = df_basketball[['年龄（岁）','身高(cm)','体重(kg)']].mean().round(0)
# print(f'运动员的平均年龄为:{avg_age}')
avg_data.index = ['平均年龄（岁）','平均身高(cm)','平均体重(kg)']
avg_data
# Out:
#         姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目        省份
# 0      陈楠   女   1983年     35     197      90  篮球       山东省
# 2     陈晓佳   女   1988年     30     180      70  篮球       江苏省
# 16   丁彦雨航   男   1993年     25     200      91  篮球  新疆维吾尔自治区
# 23     高颂   女   1992年     26     191      85  篮球    黑龙江省
# 28    郭艾伦   男   1993年     25     192      85  篮球       辽宁省
# 35    黄红枇   女   1989年     29     195      80  篮球   广西壮族自治区
# 42    黄思静   女   1996年     22     192      80  篮球       广东省
# 48    李慕豪   男   1992年     26     225     111  篮球      贵州贵阳
# 54    李珊珊   女   1987年     31     177      70  篮球     江苏省
# 73     露雯   女   1990年     28     191      78  篮球    内蒙古自治区
# 101   孙梦然   女   1992年     26     197      77  篮球       天津市
# 102   孙梦昕   女   1993年     25     190      77  篮球     山东省
# 106    睢冉   男   1992年     26     192      95  篮球       山西省
# 116    吴迪   女   1990年     28     186      72  篮球       天津市
# 124   王哲林   男   1994年     24     214     110  篮球      福建省
# ...

# %%
# 统计篮球运动员的平均年龄、身高、体重
basketball_athletes = data_groupby_project.get_group('篮球')

# %%
groupby_sex = df_basketball.groupby('性别')
for sex in groupby_sex:
    print(sex)
# Out:
# ('女',        姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目       省份
# 0     陈楠   女   1983年     35     197      90  篮球      山东省
# 2    陈晓佳   女   1988年     30     180      70  篮球      江苏省
# 23    高颂   女   1992年     26     191      85  篮球   黑龙江省
# 35   黄红枇   女   1989年     29     195      80  篮球  广西壮族自治区
# 42   黄思静   女   1996年     22     192      80  篮球      广东省
# 54   李珊珊   女   1987年     31     177      70  篮球    江苏省
# 73    露雯   女   1990年     28     191      78  篮球   内蒙古自治区
# 101  孙梦然   女   1992年     26     197      77  篮球      天津市
# 102  孙梦昕   女   1993年     25     190      77  篮球    山东省
# 116   吴迪   女   1990年     28     186      72  篮球      天津市)
# ('男',         姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目        省份
# 16   丁彦雨航   男   1993年     25     200      91  篮球  新疆维吾尔自治区
# 28    郭艾伦   男   1993年     25     192      85  篮球       辽宁省
# 48    李慕豪   男   1992年     26     225     111  篮球      贵州贵阳
# 106    睢冉   男   1992年     26     192      95  篮球       山西省
# ...

# %%
# 统计男运动员的年龄、身高、体重的极差值
man_basketball = groupby_sex.get_group('男')
print(man_basketball)
# max_min = range_data_group(man_basketball['体重(kg)'])
new = man_basketball.agg({'年龄（岁）':range_data_group,
                    '身高(cm)':range_data_group,                           
                    '体重(kg)':range_data_group
})
new
# Out:
#         姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目        省份
# 16   丁彦雨航   男   1993年     25     200      91  篮球  新疆维吾尔自治区
# 28    郭艾伦   男   1993年     25     192      85  篮球       辽宁省
# 48    李慕豪   男   1992年     26     225     111  篮球      贵州贵阳
# 106    睢冉   男   1992年     26     192      95  篮球       山西省
# 124   王哲林   男   1994年     24     214     110  篮球      福建省
# 155   易建联   男   1987年     31     213     113  篮球       广东省
# 161    周鹏   男   1989年     29     206      90  篮球       辽宁省
# 175    周琦   男   1996年     22     217      95  篮球      河南省
# 176   翟晓川   男   1993年     25     204     100  篮球      河北省
# 177   赵继伟   男   1995年     23     185      77  篮球       辽宁省
# 178   邹雨宸   男   1996年     22     208     108  篮球       辽宁省
# 年龄（岁）      9
# 身高(cm)    40
# 体重(kg)    36
# dtype: int64

# %%
df_basketball['体质指数'] = 0
df_basketball
# Out:
#         姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目        省份  体质指数
# 0      陈楠   女   1983年     35     197      90  篮球       山东省     0
# 2     陈晓佳   女   1988年     30     180      70  篮球       江苏省     0
# 16   丁彦雨航   男   1993年     25     200      91  篮球  新疆维吾尔自治区     0
# 23     高颂   女   1992年     26     191      85  篮球    黑龙江省       0
# 28    郭艾伦   男   1993年     25     192      85  篮球       辽宁省     0
# 35    黄红枇   女   1989年     29     195      80  篮球   广西壮族自治区     0
# 42    黄思静   女   1996年     22     192      80  篮球       广东省     0
# 48    李慕豪   男   1992年     26     225     111  篮球      贵州贵阳     0
# 54    李珊珊   女   1987年     31     177      70  篮球     江苏省       0
# 73     露雯   女   1990年     28     191      78  篮球    内蒙古自治区     0
# 101   孙梦然   女   1992年     26     197      77  篮球       天津市     0
# 102   孙梦昕   女   1993年     25     190      77  篮球     山东省       0
# 106    睢冉   男   1992年     26     192      95  篮球       山西省     0
# ...

# %%
# 统计篮球运动员的体质指数
bim = df_basketball['体质指数']
df_basketball['体质指数'] = df_basketball.apply(outer,axis=1)                                                             
df_basketball
# Out:
#         姓名 性别 出生年份（年）  年龄（岁）  身高(cm)  体重(kg)  项目        省份       体质指数
# 0      陈楠   女   1983年     35     197      90  篮球       山东省  23.190497
# 2     陈晓佳   女   1988年     30     180      70  篮球       江苏省  21.604938
# 16   丁彦雨航   男   1993年     25     200      91  篮球  新疆维吾尔自治区  22.750000
# 23     高颂   女   1992年     26     191      85  篮球    黑龙江省    23.299800
# 28    郭艾伦   男   1993年     25     192      85  篮球       辽宁省  23.057726
# 35    黄红枇   女   1989年     29     195      80  篮球   广西壮族自治区  21.038790
# 42    黄思静   女   1996年     22     192      80  篮球       广东省  21.701389
# 48    李慕豪   男   1992年     26     225     111  篮球      贵州贵阳  21.925926
# 54    李珊珊   女   1987年     31     177      70  篮球     江苏省    22.343516
# 73     露雯   女   1990年     28     191      78  篮球    内蒙古自治区  21.380993
# 101   孙梦然   女   1992年     26     197      77  篮球       天津市  19.840759
# 102   孙梦昕   女   1993年     25     190      77  篮球     山东省    21.329640
# ...
