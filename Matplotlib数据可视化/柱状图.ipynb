# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.bar(['Java','Pathon','Go'],[200,150,40])
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.title('月入人数')
plt.xlabel('课程')
plt.ylabel('人数')
plt.show()
