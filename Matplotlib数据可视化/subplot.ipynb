# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig,ax = plt.subplots()
ax.plot([1,2,3],[4,5,6])
plt.show()

# %%
fix,ax = plt.subplots(nrows=1,ncols=2)
ax[0].plot([1,2,3],[4,5,6]) # plot折线图
ax[1].scatter([1,2,3],[4,5,6]) # 散点图
# plt.show()
